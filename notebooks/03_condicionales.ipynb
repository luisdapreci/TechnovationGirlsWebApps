# %% [markdown]
# # 📚 Guía 03 — Condicionales
#
# ### Technovation Girls — Nivel Básico
#
# > **Notebook interactivo**: Ejecuta cada celda de código con `Shift + Enter`. ¡Modifica los ejemplos para experimentar!
#
# Hasta ahora tus programas ejecutan todas las instrucciones de arriba hacia abajo, siempre de la misma manera. Pero los programas útiles toman **decisiones**: muestran un mensaje diferente según la edad del usuario, hacen una cosa si la respuesta es correcta y otra si no lo es.
#
# Para eso existen los **condicionales**.

# %% [markdown]
# ---
#
# ## La instrucción `if`
#
# Un condicional básico tiene esta forma:
#
# ```python
# if condicion:
#     instruccion
# ```
#
# Se lee: "**Si** la condición es verdadera, ejecuta la instrucción."

# %%
edad = 15

if edad >= 12:
    print("Puedes participar en Technovation Girls")

# %% [markdown]
# ### La indentación importa
#
# La línea dentro del `if` tiene un sangrado (4 espacios). Eso se llama **indentación** y es obligatorio en Python.

# %%
# ✏️ Prueba tú misma — Cambia el valor de edad y ejecuta de nuevo
edad = 10  # Cambia este número

if edad >= 12:
    print("Puedes participar en Technovation Girls")

# %% [markdown]
# ---
#
# ## `if` y `else`
#
# Muchas veces quieres que pase algo si la condición es verdadera, **y otra cosa** si es falsa:

# %%
puntaje = 45

if puntaje >= 60:
    print("Aprobaste")
else:
    print("No aprobaste, pero puedes intentarlo de nuevo")

# %% [markdown]
# Solo uno de los dos bloques se ejecuta, nunca los dos.
#
# ---
#
# ## `if`, `elif` y `else`
#
# Cuando hay más de dos posibilidades, usas `elif` (abreviación de "else if"):

# %%
puntaje = int(input("Cual es tu puntaje? "))

if puntaje >= 90:
    print("Excelente")
elif puntaje >= 75:
    print("Muy bien")
elif puntaje >= 60:
    print("Aprobaste")
else:
    print("Necesitas practicar mas")

# %% [markdown]
# Python revisa las condiciones en orden. En cuanto encuentra una que es `True`, ejecuta ese bloque y **se salta el resto**.

# %%
# ✏️ Prueba tú misma — Escribe tu propio if/elif/else con al menos 3 opciones

# %% [markdown]
# ---
#
# ## Operadores de comparación
#
# Las condiciones se construyen con operadores de comparación. Todos devuelven `True` o `False`:
#
# | Operador | Significado | Ejemplo | Resultado |
# |---|---|---|---|
# | `==` | Igual a | `5 == 5` | `True` |
# | `!=` | Diferente de | `5 != 3` | `True` |
# | `>` | Mayor que | `7 > 10` | `False` |
# | `<` | Menor que | `3 < 8` | `True` |
# | `>=` | Mayor o igual que | `6 >= 6` | `True` |
# | `<=` | Menor o igual que | `4 <= 2` | `False` |
#
# **Cuidado con `=` vs `==`:**
# - `=` asigna un valor: `edad = 15`
# - `==` compara dos valores: `edad == 15`

# %%
# Prueba los operadores de comparación directamente
print(5 == 5)
print(5 != 3)
print(7 > 10)
print(3 < 8)

# %% [markdown]
# ---
#
# ## Operadores lógicos
#
# Puedes combinar varias condiciones usando operadores lógicos:
#
# ### `and` — las dos condiciones deben ser verdaderas

# %%
edad = 14
tiene_permiso = True

if edad >= 12 and tiene_permiso:
    print("Puedes entrar")

# %% [markdown]
# ### `or` — al menos una condición debe ser verdadera

# %%
dia = "sabado"

if dia == "sabado" or dia == "domingo":
    print("Es fin de semana")

# %% [markdown]
# ### `not` — invierte el valor de la condición

# %%
esta_lloviendo = False

if not esta_lloviendo:
    print("Buen dia para salir")

# %% [markdown]
# ### Tabla de verdad
#
# | `a` | `b` | `a and b` | `a or b` | `not a` |
# |---|---|---|---|---|
# | True | True | True | True | False |
# | True | False | False | True | False |
# | False | True | False | True | True |
# | False | False | False | False | True |

# %% [markdown]
# ---
#
# ## Condicionales anidados
#
# Puedes poner un `if` dentro de otro `if`. Esto se llama **anidamiento**:

# %%
tiene_cuenta = True
saldo = 150

if tiene_cuenta:
    if saldo >= 100:
        print("Puedes realizar la compra")
    else:
        print("Saldo insuficiente")
else:
    print("Primero debes crear una cuenta")

# %% [markdown]
# ---
#
# ## Comparar texto

# %%
respuesta = input("Deseas continuar? (si/no) ")

if respuesta == "si":
    print("Continuando...")
elif respuesta == "no":
    print("Hasta luego")
else:
    print("No entendi tu respuesta")

# %% [markdown]
# **Tip:** Usa `.lower()` para evitar problemas con mayúsculas:

# %%
respuesta = input("Deseas continuar? (si/no) ").lower()

if respuesta == "si":
    print("Continuando...")

# %% [markdown]
# ---
#
# ## Verificar si un valor está en una lista
#
# Con la palabra clave `in` puedes verificar si un valor pertenece a un conjunto:

# %%
color = input("Cual es tu color favorito? ")

if color in ["rojo", "azul", "verde"]:
    print("Es un color primario")
else:
    print("No es un color primario")

# %% [markdown]
# ---
#
# ## Ejemplo completo: clasificador de edad

# %%
nombre = input("Como te llamas? ")
edad = int(input("Cuantos anos tienes? "))

if edad < 6:
    categoria = "Infancia temprana"
elif edad < 12:
    categoria = "Ninez"
elif edad < 18:
    categoria = "Adolescencia"
else:
    categoria = "Adultez"

print(f"Hola, {nombre}. Segun tu edad ({edad} anos), estas en la etapa de: {categoria}.")

# %% [markdown]
# ---
#
# ## Ejercicio de esta guía
#
# Escribe un programa que funcione como un **quiz de una pregunta**:
#
# 1. Le muestre al usuario una pregunta de cultura general
# 2. Espere su respuesta con `input()`
# 3. Compare la respuesta con la respuesta correcta
# 4. Si es correcta, felicite al usuario
# 5. Si no, le diga cuál era la respuesta correcta
#
# **Reto extra:** Haz que la comparación no distinga entre mayúsculas y minúsculas (usa `.lower()`).

# %%
# ✏️ Escribe tu quiz aquí:

# %% [markdown]
# ---
#
# ## 🎯 Ejercicios adicionales

# %% [markdown]
# ### Ejercicio 1 — Básico: Clasificador de números
#
# Pide un número al usuario y dile si es **positivo**, **negativo** o **cero**.

# %%
# ✏️ Clasificador de números
numero = int(input("Escribe un numero: "))

# Escribe tus condiciones aquí:

# %% [markdown]
# ### Ejercicio 2 — Intermedio: Calculadora de descuentos
#
# Crea un programa que pida el total de una compra y aplique un descuento según el monto:
# - Compras mayores a $500: 20% de descuento
# - Compras entre $200 y $500: 10% de descuento
# - Compras menores a $200: sin descuento
#
# Muestra el descuento aplicado y el total final.

# %%
# ✏️ Calculadora de descuentos

# Escribe tu código aquí:

# %% [markdown]
# ### Ejercicio 3 — Avanzado: Recomendador de actividades
#
# Crea un programa que pregunte:
# 1. ¿Está lloviendo? (si/no)
# 2. ¿Cuál es la temperatura? (un número)
# 3. ¿Es de día o de noche?
#
# Según las combinaciones de respuestas, recomienda una actividad diferente. Usa `and`, `or` y `not` para combinar condiciones. Incluye al menos 5 recomendaciones diferentes.

# %%
# ✏️ Recomendador de actividades

# Escribe tu código aquí:

# %% [markdown]
# ---
#
# ## Resumen
#
# | Concepto | Qué aprendiste |
# |---|---|
# | `if` | Ejecuta un bloque si la condición es verdadera |
# | `else` | Ejecuta un bloque si la condición es falsa |
# | `elif` | Agrega más condiciones entre `if` y `else` |
# | Indentación | Espaciado obligatorio que define los bloques de código |
# | `==`, `!=`, `>`, etc. | Operadores que comparan valores |
# | `and`, `or`, `not` | Operadores lógicos para combinar condiciones |
# | `.lower()` | Convierte texto a minúsculas para comparaciones seguras |
# | `in` | Verifica si un valor está dentro de un conjunto |

# %% [markdown]
# ---
#
# ## Qué sigue
#
# En la siguiente guía aprenderás sobre **ciclos**: cómo repetir instrucciones automáticamente.
#
# ⬅️ [Anterior: 02 — Variables y tipos de datos](02_variables_y_tipos_de_datos.ipynb) | ➡️ [Siguiente: 04 — Ciclos](04_ciclos.ipynb)
