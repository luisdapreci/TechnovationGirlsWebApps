# %% [markdown]
# # 📚 Guía 02 — Variables y tipos de datos
#
# ### Technovation Girls — Nivel Básico
#
# > **Notebook interactivo**: Ejecuta cada celda de código con `Shift + Enter`. ¡Modifica los ejemplos para experimentar!
#
# En la guía anterior aprendiste a mostrar texto en pantalla con `print`. Pero un programa útil necesita recordar información: el nombre de un usuario, su edad, un puntaje, una respuesta. Para eso existen las **variables**.

# %% [markdown]
# ---
#
# ## Qué es una variable
#
# Una variable es un espacio con nombre donde guardas un dato. Piénsalo como una caja con una etiqueta: la etiqueta es el nombre de la variable y lo que hay dentro es su valor.

# %%
nombre = "Sofia"
edad = 14

# %% [markdown]
# Aquí creamos dos variables:
# - `nombre` guarda el texto `"Sofia"`
# - `edad` guarda el número `14`
#
# El símbolo `=` no significa "igual" como en matemáticas. Significa **"guarda este valor en esta variable"**. Se llama **operador de asignación**.
#
# Ahora podemos usar esas variables en cualquier parte del programa:

# %%
nombre = "Sofia"
edad = 14

print(nombre)
print(edad)

# %%
# ✏️ Prueba tú misma — Crea tus propias variables y muéstralas con print()

# %% [markdown]
# ---
#
# ## Reglas para nombrar variables
#
# | Regla | Ejemplo correcto | Ejemplo incorrecto |
# |---|---|---|
# | Solo letras, números y guion bajo `_` | `mi_nombre` | `mi-nombre` |
# | No pueden empezar con un número | `resultado2` | `2resultado` |
# | No pueden tener espacios | `nombre_completo` | `nombre completo` |
# | No pueden ser palabras reservadas de Python | `puntos` | `print`, `if`, `for` |
#
# Además, por convención (no es obligatorio pero sí recomendado):
# - Usa nombres en **minúsculas**
# - Separa palabras con guion bajo: `nombre_usuario`, `puntaje_total`
# - Usa nombres **descriptivos**: `edad` es mejor que `x`

# %% [markdown]
# ---
#
# ## Tipos de datos
#
# No todos los datos son iguales. Python distingue entre diferentes **tipos de datos**. Los más importantes para empezar son cuatro:
#
# ### 1. Cadena de texto — `str`
# Texto entre comillas simples o dobles.

# %%
saludo = "Hola, mundo"
ciudad = 'Ciudad de Mexico'
mensaje = "Bienvenida a Technovation Girls"

print(saludo)
print(ciudad)
print(mensaje)

# %% [markdown]
# ### 2. Número entero — `int`
# Números sin decimales, positivos o negativos.

# %%
edad = 15
puntaje = 200
temperatura = -3
nivel = 0

print(edad, puntaje, temperatura, nivel)

# %% [markdown]
# ### 3. Número decimal — `float`
# Números con parte decimal. Se usa punto `.`, no coma.

# %%
precio = 19.99
promedio = 8.5
altura = 1.62

print(precio, promedio, altura)

# %% [markdown]
# ### 4. Valor verdadero o falso — `bool`
# Solo puede tener dos valores: `True` (verdadero) o `False` (falso).

# %%
esta_lloviendo = False
tiene_cuenta = True
es_mayor_de_edad = False

print(esta_lloviendo, tiene_cuenta, es_mayor_de_edad)

# %% [markdown]
# ---
#
# ## Cómo saber el tipo de un dato
#
# Python tiene una función llamada `type()` que te dice de qué tipo es un valor o variable:

# %%
nombre = "Valeria"
edad = 13
altura = 1.55
es_estudiante = True

print(type(nombre))
print(type(edad))
print(type(altura))
print(type(es_estudiante))

# %%
# ✏️ Prueba tú misma — Crea variables de cada tipo y verifica con type()

# %% [markdown]
# ---
#
# ## Cambiar el valor de una variable
#
# Una variable puede cambiar de valor durante el programa. Por eso se llama "variable".

# %%
puntos = 0
print(puntos)  # muestra: 0

puntos = 10
print(puntos)  # muestra: 10

puntos = 25
print(puntos)  # muestra: 25

# %% [markdown]
# ---
#
# ## Operaciones con variables
#
# ### Con números
#
# Puedes hacer operaciones matemáticas directamente:

# %%
precio = 50
descuento = 10
precio_final = precio - descuento

print(precio_final)  # muestra: 40

# %% [markdown]
# Los operadores matemáticos en Python son:
#
# | Operador | Operación | Ejemplo | Resultado |
# |---|---|---|---|
# | `+` | Suma | `5 + 3` | `8` |
# | `-` | Resta | `10 - 4` | `6` |
# | `*` | Multiplicación | `3 * 7` | `21` |
# | `/` | División | `15 / 2` | `7.5` |
# | `//` | División entera | `15 // 2` | `7` |
# | `%` | Residuo | `15 % 2` | `1` |
# | `**` | Potencia | `2 ** 8` | `256` |
#
# ### Con texto
#
# Puedes unir cadenas de texto con el operador `+`. Esto se llama **concatenación**:

# %%
nombre = "Ana"
apellido = "Garcia"
nombre_completo = nombre + " " + apellido

print(nombre_completo)  # muestra: Ana Garcia

linea = "-" * 20
print(linea)  # muestra: --------------------

# %%
# ✏️ Prueba tú misma — Haz operaciones matemáticas con variables

# %% [markdown]
# ---
#
# ## Combinar texto y variables con f-strings
#
# Una forma muy práctica de mezclar texto fijo con variables es usando **f-strings**. Solo pones una `f` antes de las comillas y encierras las variables entre llaves `{}`:

# %%
nombre = "Camila"
edad = 16

print(f"Me llamo {nombre} y tengo {edad} anos.")

# %% [markdown]
# Esto es mucho más claro que concatenar con `+`. Usarás f-strings constantemente.

# %% [markdown]
# ---
#
# ## Pedir datos al usuario
#
# Los programas útiles le **preguntan** cosas al usuario. Para eso usamos la función `input()`:

# %%
nombre = input("Como te llamas? ")
print(f"Hola, {nombre}!")

# %% [markdown]
# **Importante:** `input()` siempre devuelve un *string*, aunque el usuario escriba un número. Si necesitas usar ese dato como número, debes convertirlo:

# %%
edad = int(input("Cuantos anos tienes? "))
print(f"En 5 anos tendras {edad + 5} anos.")

# %% [markdown]
# ---
#
# ## Conversión entre tipos de datos
#
# | Función | Convierte a | Ejemplo |
# |---|---|---|
# | `int()` | Número entero | `int("25")` → `25` |
# | `float()` | Número decimal | `float("3.14")` → `3.14` |
# | `str()` | Texto | `str(100)` → `"100"` |
# | `bool()` | Verdadero/Falso | `bool(0)` → `False` |

# %%
# ✏️ Prueba tú misma — Experimenta con conversiones de tipo
# Ejemplo: ¿qué pasa con int("abc")? ¿Y con bool(1)?

# %% [markdown]
# ---
#
# ## Ejercicio de esta guía
#
# Escribe un programa que:
#
# 1. Le pregunte al usuario su nombre
# 2. Le pregunte su edad
# 3. Le pregunte el nombre de su ciudad
# 4. Muestre un resumen con esa información usando f-strings
#
# ```
# --- Tu perfil ---
# Nombre: Lucia
# Edad: 15 años
# Ciudad: Monterrey
# En 3 años tendrás 18 años.
# ```
#
# **Reto extra:** agrega una línea que calcule en qué año naciste (el año actual es 2026, réstale la edad).

# %%
# ✏️ Escribe tu programa aquí:

# %% [markdown]
# ---
#
# ## 🎯 Ejercicios adicionales

# %% [markdown]
# ### Ejercicio 1 — Básico: ¿Cuántos minutos has vivido?
#
# Crea variables para tu edad en años y calcula cuántos meses, días (aproximados) y horas has vivido. Muestra los resultados con f-strings.

# %%
# ✏️ Calcula tu edad en diferentes unidades
edad_anos = 15  # Cambia esto por tu edad

edad_meses = edad_anos * 12
# Continúa calculando días y horas...

# %% [markdown]
# ### Ejercicio 2 — Intermedio: Convertidor de monedas
#
# Crea un programa que le pida al usuario una cantidad en pesos mexicanos y la convierta a dólares y euros. Usa variables para los tipos de cambio (ejemplo: `1 USD = 17.5 MXN`).

# %%
# ✏️ Convertidor de monedas

# Escribe tu código aquí:

# %% [markdown]
# ### Ejercicio 3 — Avanzado: Calculadora de IMC
#
# Crea un programa que pida el peso (en kg) y la estatura (en metros) del usuario, calcule su Índice de Masa Corporal con la fórmula `IMC = peso / (estatura ** 2)` y muestre el resultado formateado con un decimal.

# %%
# ✏️ Calculadora de IMC

# Escribe tu código aquí:

# %% [markdown]
# ---
#
# ## Resumen
#
# | Concepto | Qué aprendiste |
# |---|---|
# | Variable | Espacio con nombre para guardar un dato |
# | `=` | Operador de asignación (no es "igual") |
# | `str` | Tipo de dato para texto |
# | `int` | Tipo de dato para números enteros |
# | `float` | Tipo de dato para números decimales |
# | `bool` | Tipo de dato para verdadero/falso |
# | `type()` | Función que dice de qué tipo es un dato |
# | `input()` | Función para pedirle datos al usuario |
# | f-string | Forma de mezclar texto y variables con `f"...{variable}..."` |

# %% [markdown]
# ---
#
# ## Qué sigue
#
# En la siguiente guía aprenderás sobre **condicionales**: cómo hacer que tu programa tome decisiones.
#
# ⬅️ [Anterior: 01 — Introducción a Python](01_introduccion_a_python.ipynb) | ➡️ [Siguiente: 03 — Condicionales](03_condicionales.ipynb)
